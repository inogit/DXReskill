# %%
# 必要なライブラリをインポートします
import pandas as pd # データ分析をサポートするライブラリ

# %%
# --- データの準備 ---
# 演習データを格納するdatasetsフォルダを作成します
# !mkdir -p datasets
# GitHubから演習データ(ice2.csv)をダウンロードし、datasetsフォルダに保存します
# !wget -O ./datasets/ice3.csv https://raw.githubusercontent.com/inogit/DXReskill/main/DS/MissingValues/datasets/ice3.csv

# %%
data = pd.read_csv("./datasets/ice3.csv") # データファイルを読み込み
data.isnull() # 欠損値の有無を確

# %%
# 欠損値をカウント
data.isnull().sum()

# %%
# 欠損値を持つ行データ削除をまとめて削除。
data = data.dropna()

# %%
data.isnull().sum()

# %%
# データを表示し確認
data

# %%
# 欠損値を含むデータを 再度読み込む。
data = pd.read_csv("./datasets/ice3.csv")

# %%
# 欠損に全て0をセットします。
data.fillna(0)
