# %%
import pandas as pd

# %%
data = pd.read_csv("./dataset/ice3.csv")
data.isnull()

# %%
data.isnull().sum()

# %%
data = data.dropna()

# %%
data.isnull().sum()

# %%
data

# %%
data = pd.read_csv("./dataset/ice3.csv")

# %%
data.fillna(0)
